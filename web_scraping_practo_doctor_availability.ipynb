# %%
# Importing  required Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import requests                                   
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt 
import re

# %%
Cities=["Hyderabad","Bangalore","Mumbai","Chennai","Pune","Delhi"]

# %%
# coding for getting data
Title=[]
Specification=[]
exper=[]
area=[]
fee=[]
reviews=[]
location=[]
hospital=[]

urls=["https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22dermatologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22pediatrician%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22gynecologist%2Fobstetrician%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22dermatologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22cardiologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22fixed%20prosthodontics%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22service%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22implantologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22ayurveda%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22psychologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22audiologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22speech%20therapist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22dietitian%2Fnutritionist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city={}",
      "https://www.practo.com/search/clinics?results_type=clinic&q=%5B%7B%22word%22%3A%22clinikk%20health%20hub%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22practice_group%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22nerves%20surgery%20specialist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22common_name%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22pre%20prosthetic%20surgery%20(rigid%20reconstruction)%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22service%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22alopecia%20areta%20treatment%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22service%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22gall%20bladder%20(biliary)%20stone%20treatment%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22service%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22immunity%20therapy%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22service%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22child%20occupational%20therapist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22common_name%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22chickenpox%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22symptom%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22chickenpox%20treatment%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22service%22%7D%5D&city={}",
      "https://www.practo.com/search/procedure?results_type=doctor&q=%5B%7B%22word%22%3A%22epistaxis%20treatment%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22procedure%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22tailbone%20pain%20treatment%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22service%22%7D%5D&city={}",
      "https://www.practo.com/search/procedure?results_type=doctor&q=%5B%7B%22word%22%3A%22root%20canal%20treatment%20(rct)%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22procedure%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22scleral%20contact%20lens%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22service%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22rectal%20abscess%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22symptom%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22mental%20health%20doctor%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22common_name%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22cardiac%20rehabilitation%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22service%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22skin%20care%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22service%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22skin%20whitening%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22symptom%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22hair%20loss%20treatment%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22service%22%7D%5D&city={}",
      "https://www.practo.com/search/procedure?results_type=doctor&q=%5B%7B%22word%22%3A%22hair%20transplant%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22procedure%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22damon%20system%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22service%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22ocular%20manifestation%20of%20disease%20sintemica%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22service%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22spheroid%20body%20myopathy%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22symptom%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22doppler%20scan%20in%20pregnancy%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22service%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22vaginal%20infection%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22symptom%22%7D%5D&city={}",
      "https://www.practo.com/search/procedure?results_type=doctor&q=%5B%7B%22word%22%3A%22facet%20joint%20injections%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22procedure%22%7D%5D&city={}",
      "https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22joints%20and%20musculoskeletal%20disorders%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22service%22%7D%5D&city={}"]

for i in urls:
    for j in Cities:
        url=i.format(j)
        page=requests.get(url)
        soup=BeautifulSoup(page.text)
        for x in soup.find_all("div",class_="u-border-general--bottom"):
            doctor_Title=x.find("h2",class_="doctor-name")
            doctor_specification=x.find("div",class_="u-grey_3-text")
            doctor_experience=x.find("div",{'class':"uv2-spacer--xs-top",'data-qa-id':'doctor_experience'})
            city=x.find("span",{'data-qa-id':'practice_locality'})
            consult_fees=x.find("span",{'data-qa-id':"consultation_fee"})
            patient_reviews=x.find("span",class_="o-label--success u-bold")
    
            doctor_Location=x.find("span",{'class':'u-t-capitalize','data-qa-id':'practice_city'})
            hospital_Name=x.find("span",{'class':'u-c-pointer u-t-hover-underline','data-qa-id':'doctor_clinic_name'})

            if doctor_Title is None:
                Title.append(np.nan)
            else:
                Title.append(doctor_Title.text)
            if doctor_specification is None:
                Specification.append(np.nan)
            else:
                Specification.append(doctor_specification.text)
            if doctor_experience is None:
                exper.append(np.nan)
            else:
                exper.append(doctor_experience.text)
            if city is None:
                area.append(np.nan)
            else:
                area.append(city.text)
            if consult_fees is None:
                fee.append(np.nan)
            else:
                fee.append(consult_fees.text)
            if patient_reviews is None:
                reviews.append(np.nan)
            else:
                reviews.append(patient_reviews.text)
         
            if doctor_Location is None:
                location.append(np.nan)
            else:
                location.append(doctor_Location.text)
            if hospital_Name is None:
                hospital.append(np.nan)
            else:
                hospital.append(hospital_Name.text)
                
print("len of title: ",len(Title))
print("len of specification: ",len(Specification))
print("len of experience: ",len(exper))
print("len of area: ",len(area))
print("len of fee: ",len(fee))
print("len of reviews: ",len(reviews))
print("len of location: ",len(location))
print("len of hospital: ",len(hospital))
# Out:
# len of title:  2482
# len of specification:  2482
# len of experience:  2482
# len of area:  2482
# len of fee:  2482
# len of reviews:  2482
# len of location:  2482
# len of hospital:  2482

# %%
# Sample Data Frame
df=pd.DataFrame({"Doctor_Name":Title,"Specialization":Specification,"Experience":exper,"Hospital_Name":hospital,"Area":area,"City":location,"Consultation_Fee":fee,"Recommondations":reviews})

# %%
df
# Out:
#                Doctor_Name                            Specialization  \
# 0                      NaN                                       NaN
# 1                      NaN   2 Dermatologist12 - 13 years experience
# 2           Dr. V.Shirisha  Dermatologist17 years experience overall
# 3     Dr. Soumya Podduturi  Dermatologist13 years experience overall
# 4      Dr. T N Rekha Singh  Dermatologist19 years experience overall
# ...                    ...                                       ...
# 2477       Dr. Yash Bhatia    Orthopedist12 years experience overall
# 2478     Dr. Ankit Bhartia    Orthopedist15 years experience overall
# 2479         Dr. V K Sahni    Orthopedist39 years experience overall
# 2480    Dr. Praveen Tittal    Orthopedist23 years experience overall
# 2481         Dr. S Mahanta    Orthopedist27 years experience overall
#
#                        Experience  \
# 0                             NaN
# 1                             NaN
# 2     17 years experience overall
# 3     13 years experience overall
# 4     19 years experience overall
# ...                           ...
# 2477  12 years experience overall
# 2478  15 years experience overall
# 2479  39 years experience overall
# 2480  23 years experience overall
# 2481  27 years experience overall
#
#                                      Hospital_Name                 Area  \
# 0                                              NaN                  NaN
# 1                                              NaN                  NaN
# 2                      Shirisha Skin & Hair Clinic            Kondapur,
# 3                         Oliva Skin & Hair Clinic        Secunderabad,
# 4                         Oliva Skin & Hair Clinic        Secunderabad,
# ...                                            ...                  ...
# 2477            Dr. Yash Bhatia Orthopedics Centre  New Rajendra Nagar,
# 2478  Sparsh Orthopaedics and Sports Injury Centre     Dwarka Sector 3,
# 2479                          Dr. V K Sahni Clinic           Pitampura,
# 2480         Orthopaedics and Sports Injury Clinic     Dwarka Sector 6,
# 2481                               The Bone Clinic              Dwarka,
#
#            City Consultation_Fee Recommondations
# 0           NaN              NaN             NaN
# 1           NaN              NaN             NaN
# 2     Hyderabad             ₹650            93%
# 3     Hyderabad             ₹600            96%
# 4     Hyderabad             ₹600            99%
# ...         ...              ...             ...
# 2477      Delhi            ₹1000            75%
# 2478      Delhi             ₹700            98%
# 2479      Delhi             ₹900            96%
# 2480      Delhi             ₹700            96%
# 2481      Delhi             ₹700            95%
#
# [2482 rows x 8 columns]

# %% [markdown]
# ## data cleaning

# %%
df.isnull().sum()
# Out:
# Doctor_Name         319
# Specialization      215
# Experience          319
# Hospital_Name       319
# Area                319
# City                319
# Consultation_Fee    524
# Recommondations     404
# dtype: int64

# %%
# Filling null values for Recommondations
df['Recommondations'].fillna(df['Recommondations'].mode()[0],inplace = True)

# %%
# Filling null values for consulation fee
df["Consultation_Fee"].fillna(df['Consultation_Fee'].mode()[0],inplace=True)

# %%
# filling null values for experience
df["Experience"].fillna(df['Experience'].mode()[0],inplace=True)

# %%
# Dropping all null values in the sample dataframe
df1=df.dropna(subset=["Doctor_Name","Specialization","Area","City","Hospital_Name"])

# %%
# checking null values after droping
df1.isnull().sum()
# Out:
# Doctor_Name         0
# Specialization      0
# Experience          0
# Hospital_Name       0
# Area                0
# City                0
# Consultation_Fee    0
# Recommondations     0
# dtype: int64

# %%
df1
# Out:
#                    Doctor_Name                            Specialization  \
# 2               Dr. V.Shirisha  Dermatologist17 years experience overall
# 3         Dr. Soumya Podduturi  Dermatologist13 years experience overall
# 4          Dr. T N Rekha Singh  Dermatologist19 years experience overall
# 5              Dr. Mallikarjun  Dermatologist10 years experience overall
# 6     Dr. Y Nikhil Kumar Reddy  Dermatologist12 years experience overall
# ...                        ...                                       ...
# 2477           Dr. Yash Bhatia    Orthopedist12 years experience overall
# 2478         Dr. Ankit Bhartia    Orthopedist15 years experience overall
# 2479             Dr. V K Sahni    Orthopedist39 years experience overall
# 2480        Dr. Praveen Tittal    Orthopedist23 years experience overall
# 2481             Dr. S Mahanta    Orthopedist27 years experience overall
#
#                        Experience  \
# 2     17 years experience overall
# 3     13 years experience overall
# 4     19 years experience overall
# 5     10 years experience overall
# 6     12 years experience overall
# ...                           ...
# 2477  12 years experience overall
# 2478  15 years experience overall
# 2479  39 years experience overall
# 2480  23 years experience overall
# 2481  27 years experience overall
#
#                                      Hospital_Name                 Area  \
# 2                      Shirisha Skin & Hair Clinic            Kondapur,
# 3                         Oliva Skin & Hair Clinic        Secunderabad,
# 4                         Oliva Skin & Hair Clinic        Secunderabad,
# 5                          DIVI Speciality Clinics        Chanda Nagar,
# 6                                       IRA Clinic     Suchitra Circle,
# ...                                            ...                  ...
# 2477            Dr. Yash Bhatia Orthopedics Centre  New Rajendra Nagar,
# 2478  Sparsh Orthopaedics and Sports Injury Centre     Dwarka Sector 3,
# 2479                          Dr. V K Sahni Clinic           Pitampura,
# 2480         Orthopaedics and Sports Injury Clinic     Dwarka Sector 6,
# 2481                               The Bone Clinic              Dwarka,
#
#            City Consultation_Fee Recommondations
# 2     Hyderabad             ₹650            93%
# 3     Hyderabad             ₹600            96%
# 4     Hyderabad             ₹600            99%
# 5     Hyderabad             ₹400            98%
# 6     Hyderabad             ₹500            93%
# ...         ...              ...             ...
# 2477      Delhi            ₹1000            75%
# 2478      Delhi             ₹700            98%
# 2479      Delhi             ₹900            96%
# 2480      Delhi             ₹700            96%
# 2481      Delhi             ₹700            95%
#
# [2163 rows x 8 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2163 entries, 2 to 2481
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Doctor_Name       2163 non-null   object
#  1   Specialization    2163 non-null   object
#  2   Experience        2163 non-null   object
#  3   Hospital_Name     2163 non-null   object
#  4   Area              2163 non-null   object
#  5   City              2163 non-null   object
#  6   Consultation_Fee  2163 non-null   object
#  7   Recommondations   2163 non-null   object
# dtypes: object(8)
# memory usage: 152.1+ KB

# %%
# removing unwanted data for Experience
exper_1=df1['Experience'].apply(lambda x:x.replace("years experience overall",""))

# %%
# removing unwanted data for Consultation_Fee
fee=df1["Consultation_Fee"].apply(lambda x:x.replace("₹","").replace('Free Consultation',"0"))

# %%
# removing unwanted data for recommondetions
rate=df1["Recommondations"].apply(lambda x:x.replace("%",""))

# %%
# removing unwanted data for area
area_1=df1["Area"].apply(lambda x:x.replace(",",""))

# %%
# removing unwanted data for specialization 
spc=df1["Specialization"].apply(lambda x: str(re.findall("Dentist|Gynecologist\/Obstetrician|General Physician|Ear-Nose-Throat \(ENT\)|Ayurveda|Dermatologist|Homoeopath",str(x))).replace('[',"").replace(']',"").replace("'",""))

# %%
hospitalName = df1["Hospital_Name"]
hospitalName
# Out:
# 2                        Shirisha Skin & Hair Clinic
# 3                           Oliva Skin & Hair Clinic
# 4                           Oliva Skin & Hair Clinic
# 5                            DIVI Speciality Clinics
# 6                                         IRA Clinic
#                             ...
# 2477              Dr. Yash Bhatia Orthopedics Centre
# 2478    Sparsh Orthopaedics and Sports Injury Centre
# 2479                            Dr. V K Sahni Clinic
# 2480           Orthopaedics and Sports Injury Clinic
# 2481                                 The Bone Clinic
# Name: Hospital_Name, Length: 2163, dtype: object

# %%
doc_name=df1["Doctor_Name"]
doc_name
# Out:
# 2                 Dr. V.Shirisha
# 3           Dr. Soumya Podduturi
# 4            Dr. T N Rekha Singh
# 5                Dr. Mallikarjun
# 6       Dr. Y Nikhil Kumar Reddy
#                   ...
# 2477             Dr. Yash Bhatia
# 2478           Dr. Ankit Bhartia
# 2479               Dr. V K Sahni
# 2480          Dr. Praveen Tittal
# 2481               Dr. S Mahanta
# Name: Doctor_Name, Length: 2163, dtype: object

# %%
place_1 = df1["City"]
place_1
# Out:
# 2       Hyderabad
# 3       Hyderabad
# 4       Hyderabad
# 5       Hyderabad
# 6       Hyderabad
#           ...
# 2477        Delhi
# 2478        Delhi
# 2479        Delhi
# 2480        Delhi
# 2481        Delhi
# Name: City, Length: 2163, dtype: object

# %%
# After Cleaning the Data Storing the Values In a Another Data Frame

df2=pd.DataFrame({"Doctor_Names":doc_name,"Specialization":spc,"Experience":exper_1,"Hospital_Name":hospitalName,"Area":area_1,'City':place_1,"Consultation_Fees":fee,"Doctor_recommondations":rate})

# %%
df2
# Out:
#                   Doctor_Names Specialization Experience  \
# 2               Dr. V.Shirisha  Dermatologist        17
# 3         Dr. Soumya Podduturi  Dermatologist        13
# 4          Dr. T N Rekha Singh  Dermatologist        19
# 5              Dr. Mallikarjun  Dermatologist        10
# 6     Dr. Y Nikhil Kumar Reddy  Dermatologist        12
# ...                        ...            ...        ...
# 2477           Dr. Yash Bhatia                       12
# 2478         Dr. Ankit Bhartia                       15
# 2479             Dr. V K Sahni                       39
# 2480        Dr. Praveen Tittal                       23
# 2481             Dr. S Mahanta                       27
#
#                                      Hospital_Name                Area  \
# 2                      Shirisha Skin & Hair Clinic            Kondapur
# 3                         Oliva Skin & Hair Clinic        Secunderabad
# 4                         Oliva Skin & Hair Clinic        Secunderabad
# 5                          DIVI Speciality Clinics        Chanda Nagar
# 6                                       IRA Clinic     Suchitra Circle
# ...                                            ...                 ...
# 2477            Dr. Yash Bhatia Orthopedics Centre  New Rajendra Nagar
# 2478  Sparsh Orthopaedics and Sports Injury Centre     Dwarka Sector 3
# 2479                          Dr. V K Sahni Clinic           Pitampura
# 2480         Orthopaedics and Sports Injury Clinic     Dwarka Sector 6
# 2481                               The Bone Clinic              Dwarka
#
#            City Consultation_Fees Doctor_recommondations
# 2     Hyderabad               650                    93
# 3     Hyderabad               600                    96
# 4     Hyderabad               600                    99
# 5     Hyderabad               400                    98
# 6     Hyderabad               500                    93
# ...         ...               ...                    ...
# 2477      Delhi              1000                    75
# 2478      Delhi               700                    98
# 2479      Delhi               900                    96
# 2480      Delhi               700                    96
# 2481      Delhi               700                    95
#
# [2163 rows x 8 columns]

# %%
df2.to_csv("practo_doc_info.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35768\3161005954.py in <module>
# ----> 1 df2.to_csv("practo_doc_info.csv")
#
# NameError: name 'df2' is not defined

# %%
df2.to_csv("practo_doc_info_1.csv")

# %%
# reading csv data
df3=pd.read_csv("practo_doc_info_1.csv",index_col=0)

# %%
df3
# Out:
#                   Doctor_Names Specialization Experience  \
# 2               Dr. V.Shirisha  Dermatologist        17
# 3         Dr. Soumya Podduturi  Dermatologist        13
# 4          Dr. T N Rekha Singh  Dermatologist        19
# 5              Dr. Mallikarjun  Dermatologist        10
# 6     Dr. Y Nikhil Kumar Reddy  Dermatologist        12
# ...                        ...            ...        ...
# 2477           Dr. Yash Bhatia            NaN        12
# 2478         Dr. Ankit Bhartia            NaN        15
# 2479             Dr. V K Sahni            NaN        39
# 2480        Dr. Praveen Tittal            NaN        23
# 2481             Dr. S Mahanta            NaN        27
#
#                                      Hospital_Name                Area  \
# 2                      Shirisha Skin & Hair Clinic            Kondapur
# 3                         Oliva Skin & Hair Clinic        Secunderabad
# 4                         Oliva Skin & Hair Clinic        Secunderabad
# 5                          DIVI Speciality Clinics        Chanda Nagar
# 6                                       IRA Clinic     Suchitra Circle
# ...                                            ...                 ...
# 2477            Dr. Yash Bhatia Orthopedics Centre  New Rajendra Nagar
# 2478  Sparsh Orthopaedics and Sports Injury Centre     Dwarka Sector 3
# 2479                          Dr. V K Sahni Clinic           Pitampura
# 2480         Orthopaedics and Sports Injury Clinic     Dwarka Sector 6
# 2481                               The Bone Clinic              Dwarka
#
#            City  Consultation_Fees  Doctor_recommondations
# 2     Hyderabad                650                      93
# 3     Hyderabad                600                      96
# 4     Hyderabad                600                      99
# 5     Hyderabad                400                      98
# 6     Hyderabad                500                      93
# ...         ...                ...                     ...
# 2477      Delhi               1000                      75
# 2478      Delhi                700                      98
# 2479      Delhi                900                      96
# 2480      Delhi                700                      96
# 2481      Delhi                700                      95
#
# [2163 rows x 8 columns]

# %%
# Dropping all null values in the  Above dataframe
df4=df3.dropna(subset=["Doctor_Names","Specialization","Experience","Hospital_Name","Area","City","Consultation_Fees","Doctor_recommondations"])

# %%
df4
# Out:
#                   Doctor_Names     Specialization Experience  \
# 2               Dr. V.Shirisha      Dermatologist        17
# 3         Dr. Soumya Podduturi      Dermatologist        13
# 4          Dr. T N Rekha Singh      Dermatologist        19
# 5              Dr. Mallikarjun      Dermatologist        10
# 6     Dr. Y Nikhil Kumar Reddy      Dermatologist        12
# ...                        ...                ...        ...
# 2455      Dr. Vinod Prem Anand  General Physician        23
# 2456     Dr. Pravin K Aggarwal  General Physician        42
# 2457          Dr. Poonam Verma           Ayurveda        27
# 2467      Dr. Vaseem Choudhary         Homoeopath        14
# 2468       Dr. Deepesh Gaikwad         Homoeopath        16
#
#                     Hospital_Name             Area       City  \
# 2     Shirisha Skin & Hair Clinic         Kondapur  Hyderabad
# 3        Oliva Skin & Hair Clinic     Secunderabad  Hyderabad
# 4        Oliva Skin & Hair Clinic     Secunderabad  Hyderabad
# 5         DIVI Speciality Clinics     Chanda Nagar  Hyderabad
# 6                      IRA Clinic  Suchitra Circle  Hyderabad
# ...                           ...              ...        ...
# 2455        Fortis Malar Hospital            Adyar    Chennai
# 2456        Fortis Malar Hospital            Adyar    Chennai
# 2457        Bliss Medicare Centre       Vadapalani    Chennai
# 2467            Homeo Care Clinic         Hadapsar       Pune
# 2468        Healthmate Homeopathy  Pimple Saudagar       Pune
#
#       Consultation_Fees  Doctor_recommondations
# 2                   650                      93
# 3                   600                      96
# 4                   600                      99
# 5                   400                      98
# 6                   500                      93
# ...                 ...                     ...
# 2455                700                     100
# 2456                700                      86
# 2457                600                      96
# 2467                300                      93
# 2468                600                      98
#
# [882 rows x 8 columns]

# %%
df4.isnull().sum()
# Out:
# Doctor_Names              0
# Specialization            0
# Experience                0
# Hospital_Name             0
# Area                      0
# City                      0
# Consultation_Fees         0
# Doctor_recommondations    0
# dtype: int64

# %% [markdown]
# ## Type casting

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 882 entries, 2 to 2468
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Doctor_Names            882 non-null    object
#  1   Specialization          882 non-null    object
#  2   Experience              882 non-null    object
#  3   Hospital_Name           882 non-null    object
#  4   Area                    882 non-null    object
#  5   City                    882 non-null    object
#  6   Consultation_Fees       882 non-null    int64
#  7   Doctor_recommondations  882 non-null    int64
# dtypes: int64(2), object(6)
# memory usage: 62.0+ KB

# %%
df4['Experience'] = df4["Experience"].astype("int")

# %%
df4['Doctor_recommondations']=df4['Doctor_recommondations'].astype("float")

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 882 entries, 2 to 2468
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Doctor_Names            882 non-null    object
#  1   Specialization          882 non-null    object
#  2   Experience              882 non-null    int32
#  3   Hospital_Name           882 non-null    object
#  4   Area                    882 non-null    object
#  5   City                    882 non-null    object
#  6   Consultation_Fees       882 non-null    int64
#  7   Doctor_recommondations  882 non-null    float64
# dtypes: float64(1), int32(1), int64(1), object(5)
# memory usage: 58.6+ KB

# %%
# Saving the Cleand Data Frame into CSV File
df4.to_csv('practo_docInformation.csv')

# %% [markdown]
# ### Data visualization

# %%
df5=pd.read_csv('practo_docInformation.csv')

# %%
df5
# Out:
#      Unnamed: 0              Doctor_Names     Specialization  Experience  \
# 0             2            Dr. V.Shirisha      Dermatologist          17
# 1             3      Dr. Soumya Podduturi      Dermatologist          13
# 2             4       Dr. T N Rekha Singh      Dermatologist          19
# 3             5           Dr. Mallikarjun      Dermatologist          10
# 4             6  Dr. Y Nikhil Kumar Reddy      Dermatologist          12
# ..          ...                       ...                ...         ...
# 877        2455      Dr. Vinod Prem Anand  General Physician          23
# 878        2456     Dr. Pravin K Aggarwal  General Physician          42
# 879        2457          Dr. Poonam Verma           Ayurveda          27
# 880        2467      Dr. Vaseem Choudhary         Homoeopath          14
# 881        2468       Dr. Deepesh Gaikwad         Homoeopath          16
#
#                    Hospital_Name             Area       City  \
# 0    Shirisha Skin & Hair Clinic         Kondapur  Hyderabad
# 1       Oliva Skin & Hair Clinic     Secunderabad  Hyderabad
# 2       Oliva Skin & Hair Clinic     Secunderabad  Hyderabad
# 3        DIVI Speciality Clinics     Chanda Nagar  Hyderabad
# 4                     IRA Clinic  Suchitra Circle  Hyderabad
# ..                           ...              ...        ...
# 877        Fortis Malar Hospital            Adyar    Chennai
# 878        Fortis Malar Hospital            Adyar    Chennai
# 879        Bliss Medicare Centre       Vadapalani    Chennai
# 880            Homeo Care Clinic         Hadapsar       Pune
# 881        Healthmate Homeopathy  Pimple Saudagar       Pune
#
#      Consultation_Fees  Doctor_recommondations
# 0                  650                    93.0
# 1                  600                    96.0
# 2                  600                    99.0
# 3                  400                    98.0
# 4                  500                    93.0
# ..                 ...                     ...
# 877                700                   100.0
# 878                700                    86.0
# 879                600                    96.0
# 880                300                    93.0
# 881                600                    98.0
#
# [882 rows x 9 columns]

# %%
df5.drop(['Unnamed: 0'],inplace=True,axis=1)

# %%
df5
# Out:
#                  Doctor_Names     Specialization  Experience  \
# 0              Dr. V.Shirisha      Dermatologist          17
# 1        Dr. Soumya Podduturi      Dermatologist          13
# 2         Dr. T N Rekha Singh      Dermatologist          19
# 3             Dr. Mallikarjun      Dermatologist          10
# 4    Dr. Y Nikhil Kumar Reddy      Dermatologist          12
# ..                        ...                ...         ...
# 877      Dr. Vinod Prem Anand  General Physician          23
# 878     Dr. Pravin K Aggarwal  General Physician          42
# 879          Dr. Poonam Verma           Ayurveda          27
# 880      Dr. Vaseem Choudhary         Homoeopath          14
# 881       Dr. Deepesh Gaikwad         Homoeopath          16
#
#                    Hospital_Name             Area       City  \
# 0    Shirisha Skin & Hair Clinic         Kondapur  Hyderabad
# 1       Oliva Skin & Hair Clinic     Secunderabad  Hyderabad
# 2       Oliva Skin & Hair Clinic     Secunderabad  Hyderabad
# 3        DIVI Speciality Clinics     Chanda Nagar  Hyderabad
# 4                     IRA Clinic  Suchitra Circle  Hyderabad
# ..                           ...              ...        ...
# 877        Fortis Malar Hospital            Adyar    Chennai
# 878        Fortis Malar Hospital            Adyar    Chennai
# 879        Bliss Medicare Centre       Vadapalani    Chennai
# 880            Homeo Care Clinic         Hadapsar       Pune
# 881        Healthmate Homeopathy  Pimple Saudagar       Pune
#
#      Consultation_Fees  Doctor_recommondations
# 0                  650                    93.0
# 1                  600                    96.0
# 2                  600                    99.0
# 3                  400                    98.0
# 4                  500                    93.0
# ..                 ...                     ...
# 877                700                   100.0
# 878                700                    86.0
# 879                600                    96.0
# 880                300                    93.0
# 881                600                    98.0
#
# [882 rows x 8 columns]
